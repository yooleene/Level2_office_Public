# %% [markdown]
# ## <b> M2_4. [참고용] 그래프 시각화

# %% [markdown]
# ### 1. 데이터 빈도/비율 그래프 그리기
# #### 1) Pandas plot() 메서드는 matplotlib와 결합해 다양한 시각화 도구를 제공
# ##### ① 빈도분석을 위한 Bar차트, Pie차트 뿐만 아니라 탐색적 분석을 위한 히스토그램, 산점도 생성이 가능
# ##### ② matplotlib 패키지와 연결된 pandas plot() 메서드를 통해 pandas에서 직접 그래프 생성 가능

# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
# 그래프 한글 폰트 적용
mp.rc('font', family = 'Malgun Gothic')

df = pd.read_csv('data_set/학생건강검사 데이터.csv', index_col = 'id')
df
# Out:
#        ctype  ctype_sd coedu city    city_edu sch_grade  grade  class  number  \
# id
# 0     특별/광역시         1  1.공학   서울    서울특별시교육청         초      3      1       2
# 1     특별/광역시         1  1.공학   서울    서울특별시교육청         초      5      1       4
# 2     특별/광역시         1  1.공학   서울    서울특별시교육청         초      1      1       6
# 3     특별/광역시         1  1.공학   서울    서울특별시교육청         초      3      1       8
# 4     특별/광역시         1  1.공학   서울    서울특별시교육청         초      6      1       1
# ...      ...       ...   ...  ...         ...       ...    ...    ...     ...
# 4995       시         1  1.공학   경기      경기도교육청         고      3     14      22
# 4996       시         1  3.여자   충북     충청북도교육청         고      2     11      17
# 4997       시         1  1.공학   전남     전라남도교육청         고      1     11      17
# 4998       시         1  3.여자   제주  제주특별자치도교육청         고      2     21      12
# 4999       시         1  3.여자   제주  제주특별자치도교육청         고      3     31      15
#
# ...

# %% [markdown]
# #### 2) Bar Chart

# %% [markdown]
# ###

# %%
# 성별 Bar Chart
s_count = df['sex'].value_counts()  # 개별(1개) 범주형 변수의 자료 수 계산
s_count.plot(kind = 'bar', title = '성별 학생수', figsize = (6, 4), fontsize = 14, color = [(0.3, 0.5, 0.7), (0.7, 0.5, 0.3)], rot = 0)
plt.show()

# %%
# 도시별 Bar Chart
# groupby(column) : column 기준 자료 요약, as_index : groupby 변수의 index로 사용 여부
c_count = df['city'].value_counts()
c_count.plot(kind = 'bar', title = '지역별 학생수', figsize = (8, 6), fontsize = 16)
plt.show()

# %% [markdown]
# #### 3) Pie Chart

# %%
# 성별 Pie Chart
s_count = df['sex'].value_counts()  # 개별(1개) 범주형 변수의 자료 수 계산
s_count.plot(kind = 'pie', title = '성별 학생수', figsize = (6, 6), fontsize = 14, startangle = 90, autopct = '%.2f%%', explode = (0, 0.05))
plt.show()

# %% [markdown]
# #### 4) Pandas boxplot()

# %% [markdown]
# ##### ① 데이터를 4분위로 나눈 다음 중앙값을 중심으로 1~3분위까지 박스를 그려 분포를 표현하는 그래프

# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
# 그래프 한글폰트 적용
mp.rc('font', family = 'Malgun Gothic')
df = pd.read_excel('data_set/학생건강검사 데이터.xlsx', index_col = 'id')

columns = ['height', 'weight']
bys = ['sch_grade', 'sex']
for col in columns:
    for by in bys:
        df.boxplot(column = col, by = by, figsize = (6, 4), fontsize = 16)  # 서로 다른 그룹의 by열을 그룹화하는 서로 다른 상자기름을 플로팅 함
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 그래프 한글폰트 적용
#       2 mp.rc('font', family = 'Malgun Gothic')
# ----> 3 df = pd.read_excel('data_set/학생건강검사 데이터.xlsx', index_col = 'id')
#       5 columns = ['height', 'weight']
#       6 bys = ['sch_grade', 'sex']
#
# File c:\Users\poscouser\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...

# %% [markdown]
# #### 5) Pandas hist()

# %% [markdown]
# ##### ① (연속형) 데이터를 요약하여 가로축에 계급(구간), 세로축에 빈도를 표현하는 히스토그램 그리기

# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt

# %%
# 그래프 한글폰트 적용
mp.rc('font', family = 'Malgun Gothic')
df = pd.read_csv('data_set/학생건강검사 데이터.csv', index_col = 'id')

# %%
# 데이터 전체 히스토그램
df['height'].hist()
plt.show()

# %%
# 고등학생만 필터링한 히스토그램
s_data = df.loc[df['sch_grade'] == '고']
s_data['height'].hist()
plt.show()
